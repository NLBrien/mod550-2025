# %%
# -------- INFO --------
"""
Repository: https://github.com/NLBrien/mod550-2025
Date: 2025-10-12
Author: Nathan L.Brien
Course: MOD550 - Machine Learning
Title: Semester project
Description:    copying previous MOD550-P1-NLB-datasets.py code
                to data preview data in a notebook

Last modification date: 2025-10-12
"""
# Out:
# '\nRepository: https://github.com/NLBrien/mod550-2025\nDate: 2025-10-12\nAuthor: Nathan L.Brien\nCourse: MOD550 - Machine Learning\nTitle: Semester project\nDescription:    copying previous MOD550-P1-NLB-datasets.py code\n                to data preview data in a notebook\n\nLast modification date: 2025-10-12\n'

# %%
# -------- LIBRARIES --------

from MOD550_P1_NLB_datasets import (
    grfc_data,
    total_population_data,
    total_gdp_data,
    capita_gdp_data
)

# %%
# -------- IMPORT 1 --------
## grfc - Global Report on Food Crises (GRFC)

### Print dataset shape
print(f"Dataset shape (rows, columns): {grfc_data.shape}")
### Print features list
print(grfc_data.columns)
### Preview data (5 rows default)
grfc_data.head()
# Out:
# Dataset shape (rows, columns): (1323, 34)
# Index(['ISO Code 3', 'Countries/territories', 'Region', 'GRFC edition',
#        'Year of reference', 'Selection in the GRFC', 'Selection criteria',
#        'Population group selected', 'Data availability', 'Source',
#        'Population group/\nGeographical area analysed', 'Methodology',
#        'Total country population', 'Population analysed',
#        '% pop analysed of tot country pop', 'Analysis period',
#        'Population in Phase 3 or above #', 'Population in Phase 3 or above %',
#        'LOWER BOUND Population in Phase 3 or above #',
#        'LOWER BOUND Population in Phase 3 or above %',
#        'Population in Phase 1 #', 'Population in Phase 1 %',
#        'Population in Phase 2 #', 'Population in Phase 2 %',
#        'Population in Phase 3 #', 'Population in Phase 3 %',
#        'Population in Phase 4 #', 'Population in Phase 4 %',
#        'Population in Phase 5 #', 'Population in Phase 5 %',
# ...

# %%
# -------- IMPORT 2 --------
## total_population - Total population per country

#### Print dataset shape
print(f"Dataset shape (rows, columns): {total_population_data.shape}")
#### Print features list
print(total_population_data.columns)
#### Preview data (5 rows default)
total_population_data.head()
# Out:
# Dataset shape (rows, columns): (266, 70)
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# ...

# %%
# -------- IMPORT 3 --------
## total_gdp - Total GDP per country

#### Print dataset shape
print(f"Dataset shape (rows, columns): {total_gdp_data.shape}")
#### Print features list
print(total_gdp_data.columns)
#### Preview data (5 rows default)
total_gdp_data.head()
# Out:
# Dataset shape (rows, columns): (266, 70)
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# ...

# %%
# -------- IMPORT 4 --------
## capita_gdp - GDP per capita (person) per country

#### Print dataset shape
print(f"Dataset shape (rows, columns): {capita_gdp_data.shape}")
#### Print features list
print(capita_gdp_data.columns)
#### Preview data (5 rows default)
capita_gdp_data.head()
# Out:
# Dataset shape (rows, columns): (266, 70)
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  GDP per capita (current US$)
# 1  Africa Eastern and Southern          AFE  GDP per capita (current US$)
# ...
